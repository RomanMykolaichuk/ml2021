# %% [markdown]
# # Лабораторна робота №5
#
# ### Викладача групи МІТ-31 (підгрупа 1)
#
# ### Миколайчука Романа Антоновича
# ## Завдання
#
#
#    1. Виконати вирішення задачі класифікації для наборів даних, що використовувалися в лабораторній роботі 3 з використанням Tensorflow & NN
#    5. Отримані результати викласти на github у репозиторій ml2021 в основну (default) гілку в папці Lab5.
